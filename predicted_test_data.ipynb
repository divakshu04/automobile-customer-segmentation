# %%
from segmentation_module import *

# %%
data = pd.read_csv('test.csv')
pd.set_option('display.max_rows', None)
data.head()
# Out:
#        ID  Gender Ever_Married  Age Graduated  Profession  Work_Experience  \
# 0  458989  Female          Yes   36       Yes    Engineer              0.0
# 1  458994    Male          Yes   37       Yes  Healthcare              8.0
# 2  458996  Female          Yes   69        No         NaN              0.0
# 3  459000    Male          Yes   59        No   Executive             11.0
# 4  459001  Female           No   19        No   Marketing              NaN
#
#   Spending_Score  Family_Size  Var_1
# 0            Low          1.0  Cat_6
# 1        Average          4.0  Cat_6
# 2            Low          1.0  Cat_6
# 3           High          2.0  Cat_6
# 4            Low          4.0  Cat_6

# %%
model = segmentation_model('model','scaler')

# %%
model.load_and_clean_data('test.csv')

# %%
output = model.predict_output()
output.head()
# Out:
# 83/83 [==============================] - 0s 3ms/step
#        ID  Gender Ever_Married  Age Graduated  Profession  Work_Experience  \
# 0  458989  Female          Yes   36       Yes    Engineer              0.0
# 1  458994    Male          Yes   37       Yes  Healthcare              8.0
# 2  458996  Female          Yes   69        No      Artist              0.0
# 3  459000    Male          Yes   59        No   Executive             11.0
# 4  459001  Female           No   19        No   Marketing              1.0
#
#   Spending_Score  Family_Size  Var_1 Prediction
# 0            Low          1.0  Cat_6          A
# 1        Average          4.0  Cat_6          D
# 2            Low          1.0  Cat_6          D
# 3           High          2.0  Cat_6          D
# 4            Low          4.0  Cat_6          D

# %% [markdown]
# Add the output file at your desired location

# %%
output.to_csv('A:\Data Science\Projects\Customer Segmentation\output_file.csv', index=False)
